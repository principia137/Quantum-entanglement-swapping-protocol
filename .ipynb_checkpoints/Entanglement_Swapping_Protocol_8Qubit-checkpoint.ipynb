# %%
from qiskit import *
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit import IBMQ, Aer, transpile, assemble
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from qiskit.extensions import Initialize
from qiskit_textbook.tools import random_state, array_to_latex

# %%
qr = QuantumRegister(8)
cr = ClassicalRegister(8)
qc = QuantumCircuit(qr, cr)

# %%
# %matplotlib inline
qc.draw(output='mpl')

# %%
def make_entanglement(qc, a, b):
    qc.h(a)
    qc.cx(a, b)

# %%
def make_communicate(qc, a, b):
    qc.cx(a, b)
    qc.h(a)

# %%
def measure_pair(qc, a, b):
    qc.measure(a, a)
    qc.measure(b, b)

# %%
for qubit in range(4):
    make_entanglement(qc, qubit*2, qubit*2 + 1)

# %%
qc.draw(output='mpl')

# %%
qc.barrier()
for qubit in range(1,6,2):
    make_communicate(qc, qubit, qubit+1)

# %%
qc.draw(output='mpl')

# %%
qc.barrier()
for qubit in range(1, 6, 2):
    qc.cz(qubit, 0)
    qc.cx(qubit+1, 7)

# %%
qc.draw(output='mpl')

# %%
qc.barrier()
measure_pair(qc, 0, 7)
qc.draw(output='mpl')

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(qc, backend=simulator).result()
plot_histogram(result.get_counts(qc))

# %%
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q')
qcomp = provider.get_backend('ibmq_16_melbourne')
job = execute(qc, backend=qcomp)
from qiskit.tools.monitor import job_monitor
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
result = job.result()
plot_histogram(result.get_counts(qc))

# %%
counts = result.get_counts(qc)
print(f"The experimental error rate : {(1 - (counts['00000000'] + counts['10000001'])/sum(counts.values())) * 100 :.3f}%")
# Out:
# The experimental error rate : 48.145%
